# %%
#風傳媒

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import pymysql.cursors
import time 
import os
import urllib.request
from datetime import date
#today =str(date.today())
#today ='2020-02-09'
#from docx import Document


connection = pymysql.connect(host='localhost',
                             user='root',
                             password='asd273321',
                             db='new_media',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)


options = Options()
options.experimental_options["prefs"] = {'profile.default_content_settings' : {"images":2},   
                                         'profile.managed_default_content_settings' : {"images":2}}


# document = Document()
# document.add_heading(today + '新媒體文章資料爬取', 0)
# table = document.add_table(rows=1, cols=4)

# hdr_cells = table.rows[0].cells
# hdr_cells[0].text = '標題'
# hdr_cells[1].text = '分享數'
# hdr_cells[2].text = 'Hastag'
# hdr_cells[3].text = '網站'

# row_cells = table.add_row().cells
# row_cells[0].text = ''
# row_cells[1].text = ''
# row_cells[2].text = ''
# row_cells[3].text = ''



#把圖片關掉


#         for i in range(1, 3):
#             driver.get('https://www.inside.com.tw/?page='+ str(i) )
#             sourceCode = BeautifulSoup(driver.page_source)
#             article_box = sourceCode.select('div.post_list-grid_style')[0]
#             articles = article_box.select('div.post_list_item')
#             for article in articles:
#                 title = article.select('h3.post_title')[0].text
#                 date = article.select('li.post_date')[0].text.strip().replace('/', '-')
#                 tags = article.select('a.hero_slide_tag')
#                 #製作變數＿塞進ＴＡＧ
#                 tags_string = ''
#                 for tag in tags:
#                     tags_string += tag.text + ', '
#                 if today == date:
#                     print(title)
#                     print(date)
#                     print(tags_string)
                    
#                     row_cells = table.add_row().cells
#                     row_cells[0].text = title
#                     row_cells[1].text = ''
#                     row_cells[2].text = tags_string
#                     row_cells[3].text = 'Inside'
                    
#                     sql = '''
#                     INSERT INTO `new_media`.`articles` (`title`, `date`, `tags`, `brand`)
#                     VALUES('{}', '{}', '{}', '{}')
#                     '''.format(title, date, tags_string, 'inside')
#                     cursor.execute(sql)
#                     connection.commit()
                    
#             driver.get('https://technews.tw/page/'+ str(i)+ '/')
#             sourceCode = BeautifulSoup(driver.page_source)
#             article_box = sourceCode.select('div#content')[0]
#             articles = article_box.select('header.entry-header')
#             for article in articles:
#                 title = article.select('h1.entry-title')[0].text
#                 date = article.select('span.body')[1].text.strip().replace(' 年 ','-').replace(' 月 ', '-').replace(' 日 ', '-')
#                 date = date[0:10]
#                 #tags = article.select('a[href*="category"]')
#                 tags = article.select('span.body')[2].select('a')
#                 iframe = article.select('iframe')[1]
#                 response = urllib.request.urlopen(iframe.attrs['src'])
#                 iframe_soup = BeautifulSoup(response)
#                 share = iframe_soup.select('span#u_0_2')[0].text
#                 #製作變數＿塞進ＴＡＧ
#                 tags_string = ''
#                 for tag in tags:
#                     tags_string += tag.text + ', '
#                 if today == date:
#                     print(title)
#                     print(date)
#                     print(tags_string)
#                     print(share)
                    
                    
#                     row_cells = table.add_row().cells
#                     row_cells[0].text = title
#                     row_cells[1].text = share
#                     row_cells[2].text = tags_string
#                     row_cells[3].text = 'technews'
                    
#                     sql ='''
#                     INSERT INTO `new_media`.`articles` (`title`, `date`, `tags`, `share`, `brand`)
#                     VALUES('{}', '{}', '{}', '{}', '{}')
#                     '''.format(title, date, tags_string, share, 'technews')
#                     cursor.execute(sql)
#                     connection.commit()
driver = webdriver.Chrome(os.getcwd()+'/chromedriver80', chrome_options=options)
try:
    with connection.cursor() as cursor:
        driver.get('https://www.storm.mg/articles')
        sourceCode = BeautifulSoup(driver.page_source)
        article_box = sourceCode.select('div.category_cards_wrapper')[0]
        articles = article_box.select('div.category_card')
        for article in articles:
            title = article.select('.card_title')[0].text
            date = article.select('span.info_time')[0].text
            tags = article.select('a.card_tag')
            tags_string = ''
            for tag in tags:
                tags_string += tag.text + ','
                
            
            print(title)
            print(date)
            print(tags_string)
                    
                
                
                
                
#    document.save(today + '爬取資料.docx')
    connection.close()
    driver.close()
except Exception as e:
    print(e)
    connection.close()
    driver.close()
# Out:
# /Users/xiewanzhen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:116: DeprecationWarning: use options instead of chrome_options
# 武漢肺炎．防線崩潰》南韓新增病例再破百！國務總理丁世均：局面嚴重，政府盡一切努力防止疫情擴散
# 2020-02-23 10:01
# 國際,中港澳,
# 武漢肺炎衝擊》「不確定性已是新常態」IMF總裁格奧爾基耶娃：任何經濟預測都言之過早
# 2020-02-23 10:00
# 國際,中港澳,財經,科技,
# 網球》決勝盤反撲連拿8分　謝淑薇杜拜網賽完成連霸
# 2020-02-23 09:57
# 國內,運動,綜合運動,
# 疫情升溫忙修法之餘　民眾防疫物資索取一直來「立委怎可能沒有多的？」
# 2020-02-23 09:30
# 政治,調查,
# 台灣南北部真的有差！2019全年度美食行為分析結果出爐：這四縣市美食發文成長率最高
# 2020-02-23 09:30
# 風生活,美食,趨勢,
# 避免隔離者「趴趴走」、防擾亂市場秩序！武漢肺炎修法成立委開議焦點
# 2020-02-23 09:10
# 政治,調查,
# 中俄關係新挑戰》防範武漢肺炎關閉口岸、禁止中國人入境　俄羅斯經濟恐陷入風險
# 2020-02-23 09:00
# 國際,中港澳,財經,
# 新冠肺炎》一場嚴峻的壓力測試！非常疫情考驗「中國製造」韌性
# 2020-02-23 09:00
# 中港澳,財經,
# 口罩常駐的困擾：手機無法解鎖、感覺孤立、人際冷漠，那就把臉印在口罩上！設計概念大公開
# 2020-02-23 09:00
# 風生活,設計,時事話題,
# 防疫漏洞？葉元之爆料：無家可歸的居家檢疫者到處求援24小時才被安置
# 2020-02-23 08:50
# 政治,國內,
# 防止武漢肺炎，光戴口罩還不夠！醫師提醒：別張開嘴巴
# 2020-02-23 08:40
# 國內,
# 看得到，吃不到？大數據分析口罩政策5大民怨　網友最氣的是「這條」
# 2020-02-23 08:30
# 國內,
# 想拜託老外幫忙找行李，為什麼不能用「find」？要避免出國鬧尷尬，快弄懂這篇英文用法！
# 2020-02-23 08:30
# 風生活,學習,
# 看完這部片，你就進入了大人的世界：「刺激1995」25周年紀念，全台將再次上映
# 2020-02-23 08:20
# 國內,下班經濟學,有購好康,
# 怎樣能在徵才博覽會「一試就中」？資深人資：別想單靠履歷出線，這四大地雷千萬注意
# 2020-02-23 08:00
# 風生活,學長姐說,求職必讀,
# 澀谷地標青蛙電車即將消失，引起鐵道迷的反彈！從「綠色青蛙」一窺日本鐵道史
# 2020-02-23 07:30
# 風生活,日本,
# 許劍虹觀點：談一段中日聯合防疫的故事
# 2020-02-23 07:20
# 評論,國內,軍事,歷史,專欄,
# 顧燕翎觀點：在SARS前線的日子
# 2020-02-23 07:10
# 評論,國內,專欄,
# 鄧鴻源觀點：喬丹與柯比惺惺相惜
# 2020-02-23 07:00
# 評論,國際,專欄,運動,
# 單身好久了，該如何認識新對象？達人教你成功率超高的5種交友方式，女生也能主動出擊
# 2020-02-23 07:00
# 風生活,情感,
